# %%
from text_vectorian import SpBertVectorian

tokenizer_filename = '../bert-japanese/model/wiki-ja.model'
vectorizer_filename = '../bert-japanese/model/model.ckpt-1400000'

bert_vectorian = SpBertVectorian(
    tokenizer_filename=tokenizer_filename,
    vectorizer_filename=vectorizer_filename
)
# Out:
# Using TensorFlow backend.

# %%
from text_vectorian import SentencePieceVectorian

word2vec_vectorian = SentencePieceVectorian()
# Out:
# /tmp/.keras/.models/wikija-sentencepiece_300.model
# /tmp/.keras/.models/wikija-sentencepieced_word2vec_300.model
# /tmp/.keras/.models/wikija-sentencepieced_word2vec_300.model.wv.vectors.npy
# /tmp/.keras/.models/wikija-sentencepieced_word2vec_300.model.trainables.syn1neg.npy

# %%
import numpy as np
import pandas as pd

def cossim(v1, v2):
    return np.dot(v1, v2) / (np.linalg.norm(v1) * np.linalg.norm(v2))

def get_vectors(vectorian, text):
    vectors = vectorian.fit(text).vectors
    tokens = vectorian._tokenizer._tokenize(text)
    
    return tokens, vectors

def get_df(original_text, my_text):
    data = []

    original_bert = get_vectors(bert_vectorian, original_text)
    original_word2vec = get_vectors(word2vec_vectorian, original_text)
    my_bert = get_vectors(bert_vectorian, my_text)
    my_word2vec = get_vectors(word2vec_vectorian, my_text)

    for i, token in enumerate(original_word2vec[0]):
        original_token = original_bert[0][i]
        original_bert_vector = original_bert[1][i]
        original_word2vec_vector = original_word2vec[1][i]
        my_token = my_bert[0][i]
        my_bert_vector = my_bert[1][i]
        my_word2vec_vector = my_word2vec[1][i]

        bert_sim = cossim(original_bert_vector, my_bert_vector)
        word2vec_sim = cossim(original_word2vec_vector, my_word2vec_vector)
    
        data.append((i, original_token, my_token, bert_sim, word2vec_sim))

        df = pd.DataFrame(data, columns=('index', 'original token', 'my token', 'cos diff(bert)', 'cos diff(word2vec)')).set_index('index')
        df['cos diff(bert)'] = 1- df['cos diff(bert)']
        df['cos diff(bert)'] = df['cos diff(bert)'].clip(0.01, 1).replace(0.01, 0)
        df['cos diff(word2vec)'] = 1- df['cos diff(word2vec)']
        df['cos diff(word2vec)'] = df['cos diff(word2vec)'].clip(0.01, 1).replace(0.01, 0)
        
    return df

# %%
original_text = '今日は室内が大変暑いです。'
same_text = '今日は室内が大変暑いです。'
my_text = '今日は部屋がとても寒いです。'

same_df = get_df(original_text, same_text)
diff_df = get_df(original_text, my_text)

display(same_df.style.bar())
display(diff_df.style.bar())
# Out:
# <style  type="text/css" >
#     #T_e40a9efe_23aa_11ea_a0b4_acde48001122row0_col2 {
#             width:  10em;
#              height:  80%;
#         }    #T_e40a9efe_23aa_11ea_a0b4_acde48001122row0_col3 {
#             width:  10em;
#              height:  80%;
#         }    #T_e40a9efe_23aa_11ea_a0b4_acde48001122row1_col2 {
#             width:  10em;
#              height:  80%;
#         }    #T_e40a9efe_23aa_11ea_a0b4_acde48001122row1_col3 {
#             width:  10em;
#              height:  80%;
#         }    #T_e40a9efe_23aa_11ea_a0b4_acde48001122row2_col2 {
#             width:  10em;
#              height:  80%;
#         }    #T_e40a9efe_23aa_11ea_a0b4_acde48001122row2_col3 {
#             width:  10em;
#              height:  80%;
#         }    #T_e40a9efe_23aa_11ea_a0b4_acde48001122row3_col2 {
#             width:  10em;
#              height:  80%;
#         }    #T_e40a9efe_23aa_11ea_a0b4_acde48001122row3_col3 {
#             width:  10em;
#              height:  80%;
#         }    #T_e40a9efe_23aa_11ea_a0b4_acde48001122row4_col2 {
#             width:  10em;
#              height:  80%;
#         }    #T_e40a9efe_23aa_11ea_a0b4_acde48001122row4_col3 {
#             width:  10em;
#              height:  80%;
#         }    #T_e40a9efe_23aa_11ea_a0b4_acde48001122row5_col2 {
#             width:  10em;
#              height:  80%;
#         }    #T_e40a9efe_23aa_11ea_a0b4_acde48001122row5_col3 {
#             width:  10em;
#              height:  80%;
#         }    #T_e40a9efe_23aa_11ea_a0b4_acde48001122row6_col2 {
#             width:  10em;
#              height:  80%;
#         }    #T_e40a9efe_23aa_11ea_a0b4_acde48001122row6_col3 {
#             width:  10em;
#              height:  80%;
#         }    #T_e40a9efe_23aa_11ea_a0b4_acde48001122row7_col2 {
#             width:  10em;
#              height:  80%;
#         }    #T_e40a9efe_23aa_11ea_a0b4_acde48001122row7_col3 {
#             width:  10em;
#              height:  80%;
#         }    #T_e40a9efe_23aa_11ea_a0b4_acde48001122row8_col2 {
#             width:  10em;
#              height:  80%;
#         }    #T_e40a9efe_23aa_11ea_a0b4_acde48001122row8_col3 {
#             width:  10em;
#              height:  80%;
#         }</style><table id="T_e40a9efe_23aa_11ea_a0b4_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >original token</th>        <th class="col_heading level0 col1" >my token</th>        <th class="col_heading level0 col2" >cos diff(bert)</th>        <th class="col_heading level0 col3" >cos diff(word2vec)</th>    </tr>    <tr>        <th class="index_name level0" >index</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e40a9efe_23aa_11ea_a0b4_acde48001122level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_e40a9efe_23aa_11ea_a0b4_acde48001122row0_col0" class="data row0 col0" >▁</td>
#                         <td id="T_e40a9efe_23aa_11ea_a0b4_acde48001122row0_col1" class="data row0 col1" >▁</td>
#                         <td id="T_e40a9efe_23aa_11ea_a0b4_acde48001122row0_col2" class="data row0 col2" >0</td>
#                         <td id="T_e40a9efe_23aa_11ea_a0b4_acde48001122row0_col3" class="data row0 col3" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_e40a9efe_23aa_11ea_a0b4_acde48001122level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_e40a9efe_23aa_11ea_a0b4_acde48001122row1_col0" class="data row1 col0" >今日</td>
#                         <td id="T_e40a9efe_23aa_11ea_a0b4_acde48001122row1_col1" class="data row1 col1" >今日</td>
#                         <td id="T_e40a9efe_23aa_11ea_a0b4_acde48001122row1_col2" class="data row1 col2" >0</td>
#                         <td id="T_e40a9efe_23aa_11ea_a0b4_acde48001122row1_col3" class="data row1 col3" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_e40a9efe_23aa_11ea_a0b4_acde48001122level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_e40a9efe_23aa_11ea_a0b4_acde48001122row2_col0" class="data row2 col0" >は</td>
#                         <td id="T_e40a9efe_23aa_11ea_a0b4_acde48001122row2_col1" class="data row2 col1" >は</td>
#                         <td id="T_e40a9efe_23aa_11ea_a0b4_acde48001122row2_col2" class="data row2 col2" >0</td>
#                         <td id="T_e40a9efe_23aa_11ea_a0b4_acde48001122row2_col3" class="data row2 col3" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_e40a9efe_23aa_11ea_a0b4_acde48001122level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_e40a9efe_23aa_11ea_a0b4_acde48001122row3_col0" class="data row3 col0" >室内</td>
#                         <td id="T_e40a9efe_23aa_11ea_a0b4_acde48001122row3_col1" class="data row3 col1" >室内</td>
#                         <td id="T_e40a9efe_23aa_11ea_a0b4_acde48001122row3_col2" class="data row3 col2" >0</td>
#                         <td id="T_e40a9efe_23aa_11ea_a0b4_acde48001122row3_col3" class="data row3 col3" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_e40a9efe_23aa_11ea_a0b4_acde48001122level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_e40a9efe_23aa_11ea_a0b4_acde48001122row4_col0" class="data row4 col0" >が</td>
#                         <td id="T_e40a9efe_23aa_11ea_a0b4_acde48001122row4_col1" class="data row4 col1" >が</td>
#                         <td id="T_e40a9efe_23aa_11ea_a0b4_acde48001122row4_col2" class="data row4 col2" >0</td>
#                         <td id="T_e40a9efe_23aa_11ea_a0b4_acde48001122row4_col3" class="data row4 col3" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_e40a9efe_23aa_11ea_a0b4_acde48001122level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_e40a9efe_23aa_11ea_a0b4_acde48001122row5_col0" class="data row5 col0" >大変</td>
#                         <td id="T_e40a9efe_23aa_11ea_a0b4_acde48001122row5_col1" class="data row5 col1" >大変</td>
#                         <td id="T_e40a9efe_23aa_11ea_a0b4_acde48001122row5_col2" class="data row5 col2" >0</td>
#                         <td id="T_e40a9efe_23aa_11ea_a0b4_acde48001122row5_col3" class="data row5 col3" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_e40a9efe_23aa_11ea_a0b4_acde48001122level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_e40a9efe_23aa_11ea_a0b4_acde48001122row6_col0" class="data row6 col0" >暑</td>
#                         <td id="T_e40a9efe_23aa_11ea_a0b4_acde48001122row6_col1" class="data row6 col1" >暑</td>
#                         <td id="T_e40a9efe_23aa_11ea_a0b4_acde48001122row6_col2" class="data row6 col2" >0</td>
#                         <td id="T_e40a9efe_23aa_11ea_a0b4_acde48001122row6_col3" class="data row6 col3" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_e40a9efe_23aa_11ea_a0b4_acde48001122level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_e40a9efe_23aa_11ea_a0b4_acde48001122row7_col0" class="data row7 col0" >い</td>
#                         <td id="T_e40a9efe_23aa_11ea_a0b4_acde48001122row7_col1" class="data row7 col1" >い</td>
#                         <td id="T_e40a9efe_23aa_11ea_a0b4_acde48001122row7_col2" class="data row7 col2" >0</td>
#                         <td id="T_e40a9efe_23aa_11ea_a0b4_acde48001122row7_col3" class="data row7 col3" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_e40a9efe_23aa_11ea_a0b4_acde48001122level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_e40a9efe_23aa_11ea_a0b4_acde48001122row8_col0" class="data row8 col0" >です</td>
#                         <td id="T_e40a9efe_23aa_11ea_a0b4_acde48001122row8_col1" class="data row8 col1" >です</td>
#                         <td id="T_e40a9efe_23aa_11ea_a0b4
# <style  type="text/css" >
#     #T_e410d03a_23aa_11ea_87f0_acde48001122row0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 14.6%, transparent 14.6%);
#         }    #T_e410d03a_23aa_11ea_87f0_acde48001122row0_col3 {
#             width:  10em;
#              height:  80%;
#         }    #T_e410d03a_23aa_11ea_87f0_acde48001122row1_col2 {
#             width:  10em;
#              height:  80%;
#         }    #T_e410d03a_23aa_11ea_87f0_acde48001122row1_col3 {
#             width:  10em;
#              height:  80%;
#         }    #T_e410d03a_23aa_11ea_87f0_acde48001122row2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 7.7%, transparent 7.7%);
#         }    #T_e410d03a_23aa_11ea_87f0_acde48001122row2_col3 {
#             width:  10em;
#              height:  80%;
#         }    #T_e410d03a_23aa_11ea_87f0_acde48001122row3_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 5.0%, transparent 5.0%);
#         }    #T_e410d03a_23aa_11ea_87f0_acde48001122row3_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
#         }    #T_e410d03a_23aa_11ea_87f0_acde48001122row4_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 40.4%, transparent 40.4%);
#         }    #T_e410d03a_23aa_11ea_87f0_acde48001122row4_col3 {
#             width:  10em;
#              height:  80%;
#         }    #T_e410d03a_23aa_11ea_87f0_acde48001122row5_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 12.8%, transparent 12.8%);
#         }    #T_e410d03a_23aa_11ea_87f0_acde48001122row5_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 47.4%, transparent 47.4%);
#         }    #T_e410d03a_23aa_11ea_87f0_acde48001122row6_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
#         }    #T_e410d03a_23aa_11ea_87f0_acde48001122row6_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 35.3%, transparent 35.3%);
#         }    #T_e410d03a_23aa_11ea_87f0_acde48001122row7_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 49.8%, transparent 49.8%);
#         }    #T_e410d03a_23aa_11ea_87f0_acde48001122row7_col3 {
#             width:  10em;
#              height:  80%;
#         }    #T_e410d03a_23aa_11ea_87f0_acde48001122row8_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 12.4%, transparent 12.4%);
#         }    #T_e410d03a_23aa_11ea_87f0_acde48001122row8_col3 {
#             width:  10em;
#              height:  80%;
#         }</style><table id="T_e410d03a_23aa_11ea_87f0_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >original token</th>        <th class="col_heading level0 col1" >my token</th>        <th class="col_heading level0 col2" >cos diff(bert)</th>        <th class="col_heading level0 col3" >cos diff(word2vec)</th>    </tr>    <tr>        <th class="index_name level0" >index</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e410d03a_23aa_11ea_87f0_acde48001122level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_e410d03a_23aa_11ea_87f0_acde48001122row0_col0" class="data row0 col0" >▁</td>
#                         <td id="T_e410d03a_23aa_11ea_87f0_acde48001122row0_col1" class="data row0 col1" >▁</td>
#                         <td id="T_e410d03a_23aa_11ea_87f0_acde48001122row0_col2" class="data row0 col2" >0.0653358</td>
#                         <td id="T_e410d03a_23aa_11ea_87f0_acde48001122row0_col3" class="data row0 col3" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_e410d03a_23aa_11ea_87f0_acde48001122level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_