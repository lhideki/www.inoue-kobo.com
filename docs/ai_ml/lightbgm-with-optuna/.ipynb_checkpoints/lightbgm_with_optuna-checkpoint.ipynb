# %% [markdown]
# ## データ準備

# %%
from sklearn import datasets, model_selection

features, labels = datasets.load_boston(return_X_y =True)
train_features, test_features, train_labels, test_labels = model_selection.train_test_split(features, labels, test_size=0.2, shuffle=False)
train_features, valid_features, train_labels, valid_labels = model_selection.train_test_split(train_features, train_labels, test_size=0.1, shuffle=False)

print(train_features.shape)
print(train_labels.shape)
print(valid_features.shape)
print(valid_labels.shape)
print(test_features.shape)
print(test_labels.shape)
# Out:
# (363, 13)
# (363,)
# (41, 13)
# (41,)
# (102, 13)
# (102,)

# %%
import lightgbm as lgb

trains = lgb.Dataset(train_features, train_labels)
valids = lgb.Dataset(valid_features, valid_labels)
tests = lgb.Dataset(test_features, test_labels)
# Out:
# /usr/local/var/pyenv/versions/3.6.8/lib/python3.6/site-packages/lightgbm/__init__.py:46: UserWarning: Starting from version 2.2.1, the library file in distribution wheels for macOS is built by the Apple Clang (Xcode_8.3.3) compiler.
# This means that in case of installing LightGBM from PyPI via the ``pip install lightgbm`` command, you don't need to install the gcc compiler anymore.
# Instead of that, you need to install the OpenMP library, which is required for running LightGBM on the system with the Apple Clang compiler.
# You can install the OpenMP library by the following command: ``brew install libomp``.
#   "You can install the OpenMP library by the following command: ``brew install libomp``.", UserWarning)

# %% [markdown]
# ## ハイパーパラメータ最適化

# %%
import optuna.integration.lightgbm as lgb

params = {
    'objective': 'mean_squared_error',
    'metric': 'rmse'
}
best_params, history = {}, []
model = lgb.train(params, trains, valid_sets=valids,
                    verbose_eval=False,
                    num_boost_round=50,
                    early_stopping_rounds=3,
                    best_params=best_params,
                    tuning_history=history)
# Out:
# tune_feature_fraction, val_score: 2.688676:   0%|          | 0/7 [00:00<?, ?it/s][I 2020-01-26 02:21:45,308] Finished trial#0 resulted in value: 2.6886761746551326. Current best value is 2.6886761746551326 with parameters: {'feature_fraction': 0.4}.
# tune_feature_fraction, val_score: 2.688676:  29%|##8       | 2/7 [00:00<00:00, 15.88it/s][I 2020-01-26 02:21:45,402] Finished trial#1 resulted in value: 2.72283519108031. Current best value is 2.6886761746551326 with parameters: {'feature_fraction': 0.4}.
# tune_feature_fraction, val_score: 2.688676:  43%|####2     | 3/7 [00:00<00:00, 13.50it/s][I 2020-01-26 02:21:45,502] Finished trial#2 resulted in value: 2.7519653204366064. Current best value is 2.6886761746551326 with parameters: {'feature_fraction': 0.4}.
# tune_feature_fraction, val_score: 2.569710:  43%|####2     | 3/7 [00:00<00:00, 13.50it/s][I 2020-01-26 02:21:45,590] Finished trial#3 resulted in value: 2.5697101622857192. Current best value is 2.5697101622857192 with parameters: {'feature_fraction': 0.7}.
# tune_feature_fraction, val_score: 2.569710:  71%|#######1  | 5/7 [00:00<00:00, 12.69it/s][I 2020-01-26 02:21:45,679] Finished trial#4 resulted in value: 2.679238793239045. Current best value is 2.5697101622857192 with parameters: {'feature_fraction': 0.7}.
# tune_feature_fraction, val_score: 2.569710:  71%|#######1  | 5/7 [00:00<00:00, 12.69it/s][I 2020-01-26 02:21:45,761] Finished trial#5 resulted in value: 2.6720152188083603. Current best value is 2.5697101622857192 with parameters: {'feature_fraction': 0.7}.
# tune_feature_fraction, val_score: 2.569710: 100%|##########| 7/7 [00:00<00:00, 12.41it/s][I 2020-01-26 02:21:45,848] Finished trial#6 resulted in value: 2.678768284326602. Current best value is 2.5697101622857192 with parameters: {'feature_fraction': 0.7}.
#
# tune_num_leaves, val_score: 2.569710:   0%|          | 0/20 [00:00<?, ?it/s][I 2020-01-26 02:21:45,936] Finished trial#0 resulted in value: 2.5697101622857192. Current best value is 2.5697101622857192 with parameters: {'num_leaves': 170}.
# tune_num_leaves, val_score: 2.569710:  10%|#         | 2/20 [00:00<00:01, 17.85it/s][I 2020-01-26 02:21:46,021] Finished trial#1 resulted in value: 2.5697101622857192. Current best value is 2.5697101622857192 with parameters: {'num_leaves': 170}.
# tune_num_leaves, val_score: 2.569710:  10%|#         | 2/20 [00:00<00:01, 17.85it/s][I 2020-01-26 02:21:46,104] Finished trial#2 resulted in value: 2.5697101622857192. Current best value is 2.5697101622857192 with parameters: {'num_leaves': 170}.
# tune_num_leaves, val_score: 2.569710:  20%|##        | 4/20 [00:00<00:01, 15.41it/s][I 2020-01-26 02:21:46,192] Finished trial#3 resulted in value: 2.5697101622857192. Current best value is 2.5697101622857192 with parameters: {'num_leaves': 170}.
# tune_num_leaves, val_score: 2.569710:  20%|##        | 4/20 [00:00<00:01, 15.41it/s][I 2020-01-26 02:21:46,278] Finished trial#4 resulted in value: 2.5697101622857192. Current best value is 2.5697101622857192 with parameters: {'num_leaves': 170}.
# tune_num_leaves, val_score: 2.569710:  30%|###       | 6/20 [00:00<00:01, 13.95it/s][I 2020-01-26 02:21:46,371] Finished trial#5 resulted in value: 2.5697101622857192. Current best value is 2.5697101622857192 with parameters: {'num_leaves': 170}.
# tune_num_leaves, val_score: 2.569710:  35%|###5      | 7/20 [00:00<00:01, 12.39it/s][I 2020-01-26 02:21:46,473] Finished trial#6 resulted in value: 2.5697101622857192. Current best value is 2.5697101622857192 with parameters: {'num_leaves': 170}.
# tune_num_leaves, val_score: 2.569710:  40%|####      | 8/20 [00:00<00:01, 11.21it/s][I 2020-01-26 02:21:46,587] Finished trial#7 resulted in value: 2.5697101622857192. Current best value is 2.5697101622857192 with parameters: {'num_leaves': 170}.
# tune_num_leaves, val_score: 2.569710:  45%|####5     | 9/20 [00:00<00:01, 10.80it/s][I 2020-01-26 02:21:46,681] Finished trial#8 resulted in value: 2.5697101622857192. Current best value is 2.5697101622857192 with parameters: {'num_leaves': 170}.
# tune_num_leaves, val_score: 2.569710:  45%|####5     | 9/20 [00:00<00:01, 10.80it/s][I 2020-01-26 02:21:46,769] Finished trial#9 resulted in value: 2.5697101622857192. Current best value is 2.5697101622857192 with parameters: {'num_leaves': 170}.
# tune_num_leaves, val_score: 2.569710:  55%|#####5    | 11/20 [00:00<00:00, 10.88it/s][I 2020-01-26 02:21:46,860] Finished trial#10 resulted in value: 2.5697101622857192. Current best value is 2.5697101622857192 with parameters: {'num_leaves': 170}.
# tune_num_leaves, val_score: 2.569710:  55%|#####5    | 11/20 [00:01<00:00, 10.88it/s][I 2020-01-26 02:21:46,946] Finished trial#11 resulted in value: 2.5697101622857192. Current best value is 2.5697101622857192 with parameters: {'num_leaves': 170}.
# tune_num_leaves, val_score: 2.569710:  65%|######5   | 13/20 [00:01<00:00, 10.91it/s][I 2020-01-26 02:21:47,042] Finished trial#12 resulted in value: 2.5697101622857192. Current best value is 2.5697101622857192 with parameters: {'num_leaves': 170}.
# tune_num_leaves, val_score: 2.569710:  65%|######5   | 13/20 [00:01<00:00, 10.91it/s][I 2020-01-26 02:21:47,135] Finished trial#13 resulted in value: 2.5697101622857192. Current best value is 2.5697101622857192 with parameters: {'num_leaves': 170}.
# tune_num_leaves, val_score: 2.569710:  75%|#######5  | 15/20 [00:01<00:00, 11.02it/s][I 2020-01-26 02:21:47,217] Finished trial#14 resulted in value: 2.5697101622857192. Current best value is 2.5697101622857192 with parameters: {'num_leaves': 170}.
# tune_num_leaves, val_score: 2.569710:  75%|#######5  | 15/20 [00:01<00:00, 11.02it/s][I 2020-01-26 02:21:47,301] Finished trial#15 resulted in value: 2.5697101622857192. Current best value is 2.5697101622857192 with parameters: {'num_leaves': 170}.
# tune_num_leaves, val_score: 2.569710:  85%|########5 | 17/20 [00:01<00:00, 11.27it/s][I 2020-01-26 02:21:47,387] Finished trial#16 resulted in value: 2.5697101622857192. Current best value is 2.5697101622857192 with parameters: {'num_leaves': 170}.
# tune_num_leaves, val_score: 2.569710:  85%|########5 | 17/20 [00:01<00:00, 11.27it/s][I 2020-01-26 02:21:47,460] Finished trial#17 resulted in value: 2.8796905639566. Current best value is 2.5697101622857192 with parameters: {'num_leaves': 170}.
# tune_num_leaves, val_score: 2.569710:  95%|#########5| 19/20 [00:01<00:00, 11.57it/s][I 2020-01-26 02:21:47,547] Finished trial#18 resulted in value: 2.5697101622857192. Current best value is 2.5697101622857192 with parameters: {'num_leaves': 170}.
# tune_num_leaves, val_score: 2.569710:  95%|#########5| 19/20 [00:01<00:00, 11.57it/s][I 2020-01-26 02:21:47,639] Finished trial#19 resulted in value: 2.5697101622857192. Current best value is 2.5697101622857192 with parameters: {'num_leaves': 170}.
# tune_num_leaves, val_score: 2.569710: 100%|##########| 20/20 [00:01<00:00, 11.19it/s]
# tune_bagging_fraction_and_bagging_freq, val_score: 2.569710:   0%|          | 0/10 [00:00<?, ?it/s][I 2020-01-26 02:21:47,731] Finished trial#0 resulted in value: 2.7305990904460407. Current best value is 2.7305990904460407 with parameters: {'bagging_fraction': 0.8198877360935881, 'bagging_freq': 2}.
# tune_bagging_fraction_and_bagging_freq, val_score: 2.569710:  20%|##        | 2/10 [00:00<00:00, 18.57it/s][I 2020-01-26 02:21:47,818] Finished trial#1 resulted in value: 2.962546791946026. Current best value is 2.7305990904460407 with parameters: {'bagging_fraction': 0.8198877360935881, 'bagging_freq': 2}.
# tune_bagging_fraction_and_bagging_freq, val_score: 2.569710:  20%|##        | 2/10 [00:00<00:00, 18.57it/s][I 2020-01-26 02:21:47,895] Finished trial#2 resulted in value: 2.878359377088821. Current best value is 2.7305990904460407 with parameters: {'bagging_fraction': 0.8198877360935881, 'bagging_freq': 2}.
# tune_bagging_fraction_and_bagging_freq, val_score: 2.569710:  40%|####      | 4/10 [00:00<00:00, 16.29it/s][I 2020-01-26 02:21:47,973] Finished trial#3 resulted in value: 3.157824563537428. Current best value is 2.7305990904460407 with parameters: {'bagging_fraction': 0.8198877360935881, 'bagging_freq': 2}.
# tune_bagging_fraction_and_bagging_freq, val_score: 2.569710:  40%|####      | 4/10 [00:00<00:00, 16.29it/s][I 2020-01-26 02:21:48,057] Finished trial#4 resulted in value: 2.719856335437303. Current best value is 2.719856335437303 with parameters: {'bagging_fraction': 0.8330730308588727, 'bagging_freq': 4}.
# tune_bagging_fraction_and_bagging_freq, val_score: 2.569710:  60%|######    | 6/10 [00:00<00:00, 14.73it/s][I 2020-01-26 02:21:48,138] Finished trial#5 resulted in value: 2.937132325263957. Current best value is 2.719856335437303 with parameters: {'bagging_fraction': 0.8330730308588727, 'bagging_freq': 4}.
# tune_bagging_fraction_and_bagging_freq, val_score: 2.569710:  60%|######    | 6/10 [00:00<00:00, 14.73it/s][I 2020-01-26 02:21:48,216] Finished trial#6 resulted in value: 2.780863082048549. Current best value is 2.719856335437303 with parameters: {'bagging_fraction': 0.8330730308588727, 'bagging_freq': 4}.
# tune_bagging_fraction_and_bagging_freq, val_score: 2.569710:  80%|########  | 8/10 [00:00<00:00, 14.10it/s][I 2020-01-26 02:21:48,295] Finished trial#7 resulted in value: 2.8572337544630573. Current best value is 2.719856335437303 with parameters: {'bagging_fraction': 0.8330730308588727, 'bagging_freq': 4}.
# tune_bagging_fraction_and_bagging_freq, val_score: 2.569710:  80%|########  | 8/10 [00:00<00:00, 14.10it/s][I 2020-01-26 02:21:48,376] Finished trial#8 resulted in value: 2.854540237540272. Current best value is 2.719856335437303 with parameters: {'bagging_fraction': 0.8330730308588727, 'bagging_freq': 4}.
# tune_bagging_fraction_and_bagging_freq, val_score: 2.569710: 100%|##########| 10/10 [00:00<00:00, 13.57it/s][I 2020-01-26 02:21:48,454] Finished trial#9 resulted in value: 2.652724542444383. Current best value is 2.652724542444383 with parameters: {'bagging_fraction': 0.9935396289904684, 'bagging_freq': 3}.
#
# tune_feature_fraction, val_score: 2.569710:   0%|          | 0/6 [00:00<?, ?it/s][I 2020-01-26 02:21:48,536] Finished trial#0 resulted in value: 2.5698264448366324. Current best value is 2.5698264448366324 with parameters: {'feature_fraction': 0.62}.
# tune_feature_fraction, val_score: 2.569710:  33%|###3      | 2/6 [00:00<00:00, 15.12it/s][I 2020-01-26 02:21:48,641] Finished trial#1 resulted in value: 2.5698264448366324. Current best value is 2.5698264448366324 with parameters: {'feature_fraction': 0.62}.
# tune_feature_fraction, val_score: 2.569710:  33%|###3      | 2/6 [00:00<00:00, 15.12it/s][I 2020-01-26 02:21:48,723] Finished trial#2 resulted in value: 2.5698264448366324. Current best value is 2.5698264448366324 with parameters: {'feature_fraction': 0.62}.
# tune_feature_fraction, val_score: 2.569710:  67%|######6   | 4/6 [00:00<00:00, 14.06it/s][I 2020-01-26 02:21:48,810] Finished trial#3 resulted in value: 2.5697101622857192. Current best value is 2.5697101622857192 with parameters: {'feature_fraction': 0.716}.
# tune_feature_fraction, val_score: 2.569710:  67%|######6   | 4/6 [00:00<00:00, 14.06it/s][I 2020-01-26 02:21:48,894] Finished trial#4 resulted in value: 2.5697101622857192. Current best value is 2.5697101622857192 with parameters: {'feature_fraction': 0.716}.
# tune_feature_fraction, val_score: 2.569710: 100%|##########| 6/6 [00:00<00:00, 13.28it/s][I 2020-01-26 02:21:48,978] Finished trial#5 resulted in value: 2.679238793239045. Current best value is 2.5697101622857192 with parameters: {'feature_fraction': 0.716}.
#
# tune_lambda_l1_and_lambda_l2, val_score: 2.569710:   0%|          | 0/20 [00:00<?, ?it/s][I 2020-01-26 02:21:49,062] Finished trial#0 resulted in value: 2.569710715368307. Current best value is 2.569710715368307 with parameters: {'lambda_l1': 4.572444348414122e-06, 'lambda_l2': 0.0001852270821798018}.
# tune_lambda_l1_and_lambda_l2, val_score: 2.569710:  10%|#         | 2/20 [00:00<00:01, 17.14it/s][I 2020-01-26 02:21:49,155] Finished trial#1 resulted in value: 2.5697188773830777. Current best value is 2.569710715368307 with parameters: {'lambda_l1': 4.572444348414122e-06, 'lambda_l2': 0.0001852270821798018}.
# tune_lambda_l1_and_lambda_l2, val_score: 2.569710:  10%|#         | 2/20 [00:00<00:01, 17.14it/s][I 2020-01-26 02:21:49,239] Finished trial#2 resulted in value: 2.5713132644025904. Current best value is 2.569710715368307 with parameters: {'lambda_l1': 4.572444348414122e-06, 'lambda_l2': 0.0001852270821798018}.
# tune_lambda_l1_and_lambda_l2, val_score: 2.569710:  20%|##        | 4/20 [00:00<00:01, 14.99it/s][I 2020-01-26 02:21:49,327] Finished trial#3 resulted in value: 2.5697102220630303. Current best value is 2.5697102220630303 with parameters: {'lambda_l1': 1.7090441431421934e-05, 'lambda_l2': 1.2002526799503169e-08}.
# tune_lambda_l1_and_lambda_l2, val_score: 2.569710:  20%|##        | 4/20 [00:00<00:01, 14.99it/s][I 2020-01-26 02:21:49,412] Finished trial#4 resulted in value: 2.569710163185343. Current best value is 2.569710163185343 with parameters: {'lambda_l1': 4.209850719766946e-08, 'lambda_l2': 6.809885458333381e-07}.
# tune_lambda_l1_and_lambda_l2, val_score: 2.569710:  30%|###       | 6/20 [00:00<00:01, 13.67it/s][I 2020-01-26 02:21:49,502] Finished trial#5 resulted in value: 2.5713179471038. Current best value is 2.569710163185343 with parameters: {'lambda_l1': 4.209850719766946e-08, 'lambda_l2': 6.809885458333381e-07}.
# tune_lambda_l1_and_lambda_l2, val_score: 2.525805:  30%|###       | 6/20 [00:00<00:01, 13.67it/s][I 2020-01-26 02:21:49,582] Finished trial#6 resulted in value: 2.525804721626796. Current best value is 2.525804721626796 with parameters: {'lambda_l1': 0.06383243284432372, 'lambda_l2': 2.0216312728719754}.
# tune_lambda_l1_and_lambda_l2, val_score: 2.525805:  40%|####      | 8/20 [00:00<00:00, 13.24it/s][I 2020-01-26 02:21:49,666] Finished trial#7 resulted in value: 2.5697101849193467. Current best value is 2.525804721626796 with parameters: {'lambda_l1': 0.06383243284432372, 'lambda_l2': 2.0216312728719754}.
# tune_lambda_l1_and_lambda_l2, val_score: 2.525805:  40%|####      | 8/20 [00:00<00:00, 13.24it/s][I 2020-01-26 02:21:49,751] Finished trial#8 resulted in value: 2.5697124570131495. Current best value is 2.525804721626796 with parameters: {'lambda_l1': 0.06383243284432372, 'lambda_l2': 2.0216312728719754}.
# tune_lambda_l1_and_lambda_l2, val_score: 2.525805:  50%|#####     | 10/20 [00:00<00:00, 12.72it/s][I 2020-01-26 02:21:49,841] Finished trial#9 resulted in value: 2.5697101984125648. Current best value is 2.525804721626796 with parameters: {'lambda_l1': 0.06383243284432372, 'lambda_l2': 2.0216312728719754}.
# tune_lambda_l1_and_lambda_l2, val_score: 2.525805:  50%|#####     | 10/20 [00:00<00:00, 12.72it/s][I 2020-01-26 02:21:49,950] Finished trial#10 resulted in value: 2.8276153070956624. Current best value is 2.525804721626796 with parameters: {'lambda_l1': 0.06383243284432372, 'lambda_l2': 2.0216312728719754}.
# tune_lambda_l1_and_lambda_l2, val_score: 2.525805:  60%|######    | 12/20 [00:00<00:00, 11.82it/s][I 2020-01-26 02:21:50,035] Finished trial#11 resulted in value: 2.676488996211571. Current best value is 2.525804721626796 with parameters: {'lambda_l1': 0.06383243284432372, 'lambda_l2': 2.0216312728719754}.
# tune_lambda_l1_and_lambda_l2, val_score: 2.525805:  60%|######    | 12/20 [00:01<00:00, 11.82it/s][I 2020-01-26 02:21:50,118] Finished trial#12 resulted in value: 2.622822163401965. Current best value is 2.525804721626796 with parameters: {'lambda_l1': 0.06383243284432372, 'lambda_l2': 2.0216312728719754}.
# tune_lambda_l1_and_lambda_l2, val_score: 2.525805:  70%|#######   | 14/20 [00:01<00:00, 11.91it/s][I 2020-01-26 02:21:50,199] Finished trial#13 resulted in value: 2.610966407267469. Current best value is 2.525804721626796 with parameters: {'lambda_l1': 0.06383243284432372, 'lambda_l2': 2.0216312728719754}.
# tune_lambda_l1_and_lambda_l2, val_score: 2.525805:  70%|#######   | 14/20 [00:01<00:00, 11.91it/s][I 2020-01-26 02:21:50,280] Finished trial#14 resulted in value: 2.6417336050748115. Current best value is 2.525804721626796 with parameters: {'lambda_l1': 0.06383243284432372, 'lambda_l2': 2.0216312728719754}.
# tune_lambda_l1_and_lambda_l2, val_score: 2.525805:  80%|########  | 16/20 [00:01<00:00, 12.01it/s][I 2020-01-26 02:21:50,362] Finished trial#15 resulted in value: 2.6415010645794146. Current best value is 2.525804721626796 with parameters: {'lambda_l1': 0.06383243284432372, 'lambda_l2': 2.0216312728719754}.
# tune_lambda_l1_and_lambda_l2, val_score: 2.525805:  80%|########  | 16/20 [00:01<00:00, 12.01it/s][I 2020-01-26 02:21:50,450] Finished trial#16 resulted in value: 2.569710162937925. Current best value is 2.525804721626796 with parameters: {'lambda_l1': 0.06383243284432372, 'lambda_l2': 2.0216312728719754}.
# tune_lambda_l1_and_lambda_l2, val_score: 2.525805:  90%|######### | 18/20 [00:01<00:00, 11.89it/s][I 2020-01-26 02:21:50,535] Finished trial#17 resulted in value: 2.62286789592724. Current best value is 2.525804721626796 with parameters: {'lambda_l1': 0.06383243284432372, 'lambda_l2': 2.0216312728719754}.
# tune_lambda_l1_and_lambda_l2, val_score: 2.525805:  90%|######### | 18/20 [00:01<00:00, 11.89it/s][I 2020-01-26 02:21:50,616] Finished trial#18 resulted in value: 2.669565384080039. Current best value is 2.525804721626796 with parameters: {'lambda_l1': 0.06383243284432372, 'lambda_l2': 2.0216312728719754}.
# tune_lambda_l1_and_lambda_l2, val_score: 2.525805: 100%|##########| 20/20 [00:01<00:00, 11.97it/s][I 2020-01-26 02:21:50,699] Finished trial#19 resulted in value: 2.569716331822459. Current best value is 2.525804721626796 with parameters: {'lambda_l1': 0.06383243284432372, 'lambda_l2': 2.0216312728719754}.
#
# tune_min_child_samples, val_score: 2.525805:   0%|          | 0/5 [00:00<?, ?it/s][I 2020-01-26 02:21:50,782] Finished trial#0 resulted in value: 2.631707052673922. Current best value is 2.631707052673922 with parameters: {'min_child_samples': 5}.
# tune_min_child_samples, val_score: 2.525805:  40%|####      | 2/5 [00:00<00:00, 17.28it/s][I 2020-01-26 02:21:50,870] Finished trial#1 resulted in value: 2.676316626703411. Current best value is 2.631707052673922 with parameters: {'min_child_samples': 5}.
# tune_min_child_samples, val_score: 2.525805:  40%|####      | 2/5 [00:00<00:00, 17.28it/s][I 2020-01-26 02:21:50,944] Finished trial#2 resulted in value: 2.790422068421255. Current best value is 2.631707052673922 with parameters: {'min_child_samples': 5}.
# tune_min_child_samples, val_score: 2.525805:  80%|########  | 4/5 [00:00<00:00, 16.08it/s][I 2020-01-26 02:21:51,016] Finished trial#3 resulted in value: 3.319335712437327. Current best value is 2.631707052673922 with parameters: {'min_child_samples': 5}.
# tune_min_child_samples, val_score: 2.525805:  80%|########  | 4/5 [00:00<00:00, 16.08it/s][I 2020-01-26 02:21:51,088] Finished trial#4 resulted in value: 3.824275525523972. Current best value is 2.631707052673922 with parameters: {'min_child_samples': 5}.
# tune_min_child_samples, val_score: 2.525805: 100%|##########| 5/5 [00:00<00:00, 12.93it/s]

# %%
best_params
# Out:
# {'lambda_l1': 0.06383243284432372,
#  'lambda_l2': 2.0216312728719754,
#  'num_leaves': 31,
#  'feature_fraction': 0.7,
#  'bagging_fraction': 1.0,
#  'bagging_freq': 0,
#  'min_child_samples': 20}

# %%
param_defaults = {
    'lambda_l1': 0.0,
    'lambda_l2': 0.0,
    'num_leaves': 31,
    'feature_fraction':  1.0,
    'bagging_fraction':  1.0,
    'bagging_freq': 0,
    'min_child_samples': 20
}

# %%
# %matplotlib inline
import pandas as pd
import seaborn as sns

study_vals = []
for h in history:
    vals = {}
    for k, v in best_params.items():
        if k in h['value']:
            dic = eval(h['value'])
            col = k
            val = dic[k]
        else:
            col = k
            val = param_defaults[k]
        vals[col] = val
        vals['score'] = h['val_score']
    study_vals.append(vals)

study_df = pd.DataFrame(study_vals)
sns.pairplot(study_df, kind='reg')

# %% [markdown]
# ## 見つけたパラメータでモデル作成

# %%
import lightgbm as lgb_original
from sklearn.metrics import r2_score

model = lgb_original.train(params, trains, num_boost_round=100, valid_sets=valids, early_stopping_rounds=3, verbose_eval=False)
predicts = model.predict(test_features)
base_r2 = r2_score(test_labels, predicts)

# %%
merged_params = dict(params, **best_params)
model = lgb_original.train(merged_params, trains, num_boost_round=100, valid_sets=valids, early_stopping_rounds=3, verbose_eval=False)
predicts = model.predict(test_features)
best_r2 = r2_score(test_labels, predicts)

# %%
print(f'Base params: {params}')
print(f'Best params: {merged_params}')
print(f'Base: {base_r2}, Best: {best_r2}, Diff: {best_r2 - base_r2}')
# Out:
# Base params: {'objective': 'mean_squared_error', 'metric': 'rmse'}
# Best params: {'objective': 'mean_squared_error', 'metric': 'rmse', 'lambda_l1': 0.06383243284432372, 'lambda_l2': 2.0216312728719754, 'num_leaves': 31, 'feature_fraction': 0.7, 'bagging_fraction': 1.0, 'bagging_freq': 0, 'min_child_samples': 20}
# Base: 0.7694199988436563, Best: 0.7714541803600758, Diff: 0.002034181516419542
