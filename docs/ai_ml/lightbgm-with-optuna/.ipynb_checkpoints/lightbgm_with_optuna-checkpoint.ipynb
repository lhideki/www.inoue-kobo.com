# %% [markdown]
# ## データ準備

# %%
from sklearn import datasets, model_selection

features, labels = datasets.load_boston(return_X_y =True)
train_features, test_features, train_labels, test_labels = model_selection.train_test_split(features, labels, test_size=0.2)
train_features, valid_features, train_labels, valid_labels = model_selection.train_test_split(train_features, train_labels, test_size=0.1)

print(train_features.shape)
print(train_labels.shape)
print(valid_features.shape)
print(valid_labels.shape)
print(test_features.shape)
print(test_labels.shape)
# Out:
# (363, 13)
# (363,)
# (41, 13)
# (41,)
# (102, 13)
# (102,)

# %%
import lightgbm as lgb

trains = lgb.Dataset(train_features, train_labels)
valids = lgb.Dataset(valid_features, valid_labels)
tests = lgb.Dataset(test_features, test_labels)
# Out:
# /usr/local/var/pyenv/versions/3.6.8/lib/python3.6/site-packages/lightgbm/__init__.py:46: UserWarning: Starting from version 2.2.1, the library file in distribution wheels for macOS is built by the Apple Clang (Xcode_8.3.3) compiler.
# This means that in case of installing LightGBM from PyPI via the ``pip install lightgbm`` command, you don't need to install the gcc compiler anymore.
# Instead of that, you need to install the OpenMP library, which is required for running LightGBM on the system with the Apple Clang compiler.
# You can install the OpenMP library by the following command: ``brew install libomp``.
#   "You can install the OpenMP library by the following command: ``brew install libomp``.", UserWarning)

# %% [markdown]
# ## ハイパーパラメータ最適化

# %%
import optuna.integration.lightgbm as lgb

params = {
    'objective': 'mean_squared_error',
    'metric': 'rmse'
}
best_params, history = {}, []
model = lgb.train(params, trains, valid_sets=valids,
                    verbose_eval=False,
                    num_boost_round=100,
                    early_stopping_rounds=5,
                    best_params=best_params,
                    tuning_history=history)
# Out:
# tune_feature_fraction, val_score: 4.714621:   0%|          | 0/7 [00:00<?, ?it/s][I 2020-01-25 12:39:14,644] Finished trial#0 resulted in value: 4.714620881871943. Current best value is 4.714620881871943 with parameters: {'feature_fraction': 0.4}.
# tune_feature_fraction, val_score: 4.714621:  29%|##8       | 2/7 [00:00<00:00, 13.55it/s][I 2020-01-25 12:39:14,741] Finished trial#1 resulted in value: 4.883415797038567. Current best value is 4.714620881871943 with parameters: {'feature_fraction': 0.4}.
# tune_feature_fraction, val_score: 4.714621:  43%|####2     | 3/7 [00:00<00:00, 11.40it/s][I 2020-01-25 12:39:14,863] Finished trial#2 resulted in value: 4.98694218955178. Current best value is 4.714620881871943 with parameters: {'feature_fraction': 0.4}.
# tune_feature_fraction, val_score: 4.714621:  57%|#####7    | 4/7 [00:00<00:00,  7.21it/s][I 2020-01-25 12:39:15,121] Finished trial#3 resulted in value: 4.871269426996548. Current best value is 4.714620881871943 with parameters: {'feature_fraction': 0.4}.
# tune_feature_fraction, val_score: 4.714621:  57%|#####7    | 4/7 [00:00<00:00,  7.21it/s][I 2020-01-25 12:39:15,215] Finished trial#4 resulted in value: 4.751700681924328. Current best value is 4.714620881871943 with parameters: {'feature_fraction': 0.4}.
# tune_feature_fraction, val_score: 4.621956:  86%|########5 | 6/7 [00:00<00:00,  7.97it/s][I 2020-01-25 12:39:15,309] Finished trial#5 resulted in value: 4.62195601109056. Current best value is 4.62195601109056 with parameters: {'feature_fraction': 0.8999999999999999}.
# tune_feature_fraction, val_score: 4.610915:  86%|########5 | 6/7 [00:00<00:00,  7.97it/s][I 2020-01-25 12:39:15,391] Finished trial#6 resulted in value: 4.610914999935319. Current best value is 4.610914999935319 with parameters: {'feature_fraction': 1.0}.
# tune_feature_fraction, val_score: 4.610915: 100%|##########| 7/7 [00:00<00:00,  8.20it/s]
# tune_num_leaves, val_score: 4.610915:   0%|          | 0/20 [00:00<?, ?it/s][I 2020-01-25 12:39:15,487] Finished trial#0 resulted in value: 4.610914999935319. Current best value is 4.610914999935319 with parameters: {'num_leaves': 203}.
# tune_num_leaves, val_score: 4.610915:  10%|#         | 2/20 [00:00<00:01, 17.34it/s][I 2020-01-25 12:39:15,570] Finished trial#1 resulted in value: 4.610914999935319. Current best value is 4.610914999935319 with parameters: {'num_leaves': 203}.
# tune_num_leaves, val_score: 4.610915:  10%|#         | 2/20 [00:00<00:01, 17.34it/s][I 2020-01-25 12:39:15,669] Finished trial#2 resulted in value: 4.610914999935319. Current best value is 4.610914999935319 with parameters: {'num_leaves': 203}.
# tune_num_leaves, val_score: 4.610915:  20%|##        | 4/20 [00:00<00:01, 14.54it/s][I 2020-01-25 12:39:15,763] Finished trial#3 resulted in value: 4.610914999935319. Current best value is 4.610914999935319 with parameters: {'num_leaves': 203}.
# tune_num_leaves, val_score: 4.610915:  20%|##        | 4/20 [00:00<00:01, 14.54it/s][I 2020-01-25 12:39:15,855] Finished trial#4 resulted in value: 4.610914999935319. Current best value is 4.610914999935319 with parameters: {'num_leaves': 203}.
# tune_num_leaves, val_score: 4.610915:  30%|###       | 6/20 [00:00<00:01, 13.29it/s][I 2020-01-25 12:39:15,938] Finished trial#5 resulted in value: 4.610914999935319. Current best value is 4.610914999935319 with parameters: {'num_leaves': 203}.
# tune_num_leaves, val_score: 4.610915:  30%|###       | 6/20 [00:00<00:01, 13.29it/s][I 2020-01-25 12:39:16,017] Finished trial#6 resulted in value: 4.610914999935319. Current best value is 4.610914999935319 with parameters: {'num_leaves': 203}.
# tune_num_leaves, val_score: 4.610915:  40%|####      | 8/20 [00:00<00:00, 12.71it/s][I 2020-01-25 12:39:16,112] Finished trial#7 resulted in value: 4.610914999935319. Current best value is 4.610914999935319 with parameters: {'num_leaves': 203}.
# tune_num_leaves, val_score: 4.610915:  40%|####      | 8/20 [00:00<00:00, 12.71it/s][I 2020-01-25 12:39:16,197] Finished trial#8 resulted in value: 4.610914999935319. Current best value is 4.610914999935319 with parameters: {'num_leaves': 203}.
# tune_num_leaves, val_score: 4.610915:  50%|#####     | 10/20 [00:00<00:00, 12.46it/s][I 2020-01-25 12:39:16,280] Finished trial#9 resulted in value: 4.610914999935319. Current best value is 4.610914999935319 with parameters: {'num_leaves': 203}.
# tune_num_leaves, val_score: 4.610915:  50%|#####     | 10/20 [00:00<00:00, 12.46it/s][I 2020-01-25 12:39:16,364] Finished trial#10 resulted in value: 4.610914999935319. Current best value is 4.610914999935319 with parameters: {'num_leaves': 203}.
# tune_num_leaves, val_score: 4.610915:  60%|######    | 12/20 [00:00<00:00, 12.23it/s][I 2020-01-25 12:39:16,452] Finished trial#11 resulted in value: 4.610914999935319. Current best value is 4.610914999935319 with parameters: {'num_leaves': 203}.
# tune_num_leaves, val_score: 4.610915:  60%|######    | 12/20 [00:01<00:00, 12.23it/s][I 2020-01-25 12:39:16,524] Finished trial#12 resulted in value: 4.799156246847483. Current best value is 4.610914999935319 with parameters: {'num_leaves': 203}.
# tune_num_leaves, val_score: 4.610915:  70%|#######   | 14/20 [00:01<00:00, 12.34it/s][I 2020-01-25 12:39:16,612] Finished trial#13 resulted in value: 4.610914999935319. Current best value is 4.610914999935319 with parameters: {'num_leaves': 203}.
# tune_num_leaves, val_score: 4.610915:  70%|#######   | 14/20 [00:01<00:00, 12.34it/s][I 2020-01-25 12:39:16,699] Finished trial#14 resulted in value: 4.610914999935319. Current best value is 4.610914999935319 with parameters: {'num_leaves': 203}.
# tune_num_leaves, val_score: 4.610915:  80%|########  | 16/20 [00:01<00:00, 12.33it/s][I 2020-01-25 12:39:16,771] Finished trial#15 resulted in value: 4.94910866756803. Current best value is 4.610914999935319 with parameters: {'num_leaves': 203}.
# tune_num_leaves, val_score: 4.610915:  80%|########  | 16/20 [00:01<00:00, 12.33it/s][I 2020-01-25 12:39:16,851] Finished trial#16 resulted in value: 4.610914999935319. Current best value is 4.610914999935319 with parameters: {'num_leaves': 203}.
# tune_num_leaves, val_score: 4.610915:  90%|######### | 18/20 [00:01<00:00, 12.36it/s][I 2020-01-25 12:39:16,932] Finished trial#17 resulted in value: 4.610914999935319. Current best value is 4.610914999935319 with parameters: {'num_leaves': 203}.
# tune_num_leaves, val_score: 4.610915:  90%|######### | 18/20 [00:01<00:00, 12.36it/s][I 2020-01-25 12:39:17,018] Finished trial#18 resulted in value: 4.610914999935319. Current best value is 4.610914999935319 with parameters: {'num_leaves': 203}.
# tune_num_leaves, val_score: 4.610915: 100%|##########| 20/20 [00:01<00:00, 11.90it/s][I 2020-01-25 12:39:17,117] Finished trial#19 resulted in value: 4.610914999935319. Current best value is 4.610914999935319 with parameters: {'num_leaves': 203}.
#
# tune_bagging_fraction_and_bagging_freq, val_score: 4.610915:   0%|          | 0/10 [00:00<?, ?it/s][I 2020-01-25 12:39:17,208] Finished trial#0 resulted in value: 4.61917214596909. Current best value is 4.61917214596909 with parameters: {'bagging_fraction': 0.971483776231604, 'bagging_freq': 4}.
# tune_bagging_fraction_and_bagging_freq, val_score: 4.610915:  20%|##        | 2/10 [00:00<00:00, 18.64it/s][I 2020-01-25 12:39:17,288] Finished trial#1 resulted in value: 5.257649491016331. Current best value is 4.61917214596909 with parameters: {'bagging_fraction': 0.971483776231604, 'bagging_freq': 4}.
# tune_bagging_fraction_and_bagging_freq, val_score: 4.610915:  30%|###       | 3/10 [00:00<00:00, 13.74it/s][I 2020-01-25 12:39:17,402] Finished trial#2 resulted in value: 4.637373155952917. Current best value is 4.61917214596909 with parameters: {'bagging_fraction': 0.971483776231604, 'bagging_freq': 4}.
# tune_bagging_fraction_and_bagging_freq, val_score: 4.610915:  40%|####      | 4/10 [00:00<00:00, 11.19it/s][I 2020-01-25 12:39:17,531] Finished trial#3 resulted in value: 5.035320765533678. Current best value is 4.61917214596909 with parameters: {'bagging_fraction': 0.971483776231604, 'bagging_freq': 4}.
# tune_bagging_fraction_and_bagging_freq, val_score: 4.610915:  50%|#####     | 5/10 [00:00<00:00,  9.80it/s][I 2020-01-25 12:39:17,668] Finished trial#4 resulted in value: 4.828808742264792. Current best value is 4.61917214596909 with parameters: {'bagging_fraction': 0.971483776231604, 'bagging_freq': 4}.
# tune_bagging_fraction_and_bagging_freq, val_score: 4.604077:  60%|######    | 6/10 [00:00<00:00,  9.50it/s][I 2020-01-25 12:39:17,774] Finished trial#5 resulted in value: 4.604076978534881. Current best value is 4.604076978534881 with parameters: {'bagging_fraction': 0.8764226042397782, 'bagging_freq': 5}.
# tune_bagging_fraction_and_bagging_freq, val_score: 4.604077:  60%|######    | 6/10 [00:00<00:00,  9.50it/s][I 2020-01-25 12:39:17,849] Finished trial#6 resulted in value: 4.797682651749426. Current best value is 4.604076978534881 with parameters: {'bagging_fraction': 0.8764226042397782, 'bagging_freq': 5}.
# tune_bagging_fraction_and_bagging_freq, val_score: 4.604077:  80%|########  | 8/10 [00:00<00:00, 10.42it/s][I 2020-01-25 12:39:17,922] Finished trial#7 resulted in value: 5.089477491738895. Current best value is 4.604076978534881 with parameters: {'bagging_fraction': 0.8764226042397782, 'bagging_freq': 5}.
# tune_bagging_fraction_and_bagging_freq, val_score: 4.604077:  80%|########  | 8/10 [00:00<00:00, 10.42it/s][I 2020-01-25 12:39:17,993] Finished trial#8 resulted in value: 4.944014918303536. Current best value is 4.604076978534881 with parameters: {'bagging_fraction': 0.8764226042397782, 'bagging_freq': 5}.
# tune_bagging_fraction_and_bagging_freq, val_score: 4.604077: 100%|##########| 10/10 [00:00<00:00, 11.19it/s][I 2020-01-25 12:39:18,070] Finished trial#9 resulted in value: 4.901436569818603. Current best value is 4.604076978534881 with parameters: {'bagging_fraction': 0.8764226042397782, 'bagging_freq': 5}.
#
# tune_feature_fraction, val_score: 4.604077:   0%|          | 0/3 [00:00<?, ?it/s][I 2020-01-25 12:39:18,148] Finished trial#0 resulted in value: 4.723975522381595. Current best value is 4.723975522381595 with parameters: {'feature_fraction': 0.92}.
# tune_feature_fraction, val_score: 4.604077:  67%|######6   | 2/3 [00:00<00:00, 18.09it/s][I 2020-01-25 12:39:18,236] Finished trial#1 resulted in value: 4.7200016004549. Current best value is 4.7200016004549 with parameters: {'feature_fraction': 0.9520000000000001}.
# tune_feature_fraction, val_score: 4.604077:  67%|######6   | 2/3 [00:00<00:00, 18.09it/s][I 2020-01-25 12:39:18,315] Finished trial#2 resulted in value: 4.7200016004549. Current best value is 4.7200016004549 with parameters: {'feature_fraction': 0.9520000000000001}.
# tune_feature_fraction, val_score: 4.604077: 100%|##########| 3/3 [00:00<00:00, 12.38it/s]
# tune_lambda_l1_and_lambda_l2, val_score: 4.604077:   0%|          | 0/20 [00:00<?, ?it/s][I 2020-01-25 12:39:18,398] Finished trial#0 resulted in value: 4.604076979455367. Current best value is 4.604076979455367 with parameters: {'lambda_l1': 4.483407399222182e-07, 'lambda_l2': 9.352079392317614e-08}.
# tune_lambda_l1_and_lambda_l2, val_score: 4.604077:  10%|#         | 2/20 [00:00<00:00, 18.72it/s][I 2020-01-25 12:39:18,489] Finished trial#1 resulted in value: 4.6198901975582745. Current best value is 4.604076979455367 with parameters: {'lambda_l1': 4.483407399222182e-07, 'lambda_l2': 9.352079392317614e-08}.
# tune_lambda_l1_and_lambda_l2, val_score: 4.604077:  15%|#5        | 3/20 [00:00<00:01, 14.83it/s][I 2020-01-25 12:39:18,593] Finished trial#2 resulted in value: 4.676080243869447. Current best value is 4.604076979455367 with parameters: {'lambda_l1': 4.483407399222182e-07, 'lambda_l2': 9.352079392317614e-08}.
# tune_lambda_l1_and_lambda_l2, val_score: 4.604077:  15%|#5        | 3/20 [00:00<00:01, 14.83it/s][I 2020-01-25 12:39:18,681] Finished trial#3 resulted in value: 4.604077007744036. Current best value is 4.604076979455367 with parameters: {'lambda_l1': 4.483407399222182e-07, 'lambda_l2': 9.352079392317614e-08}.
# tune_lambda_l1_and_lambda_l2, val_score: 4.604077:  25%|##5       | 5/20 [00:00<00:01, 13.58it/s][I 2020-01-25 12:39:18,760] Finished trial#4 resulted in value: 4.604083126069293. Current best value is 4.604076979455367 with parameters: {'lambda_l1': 4.483407399222182e-07, 'lambda_l2': 9.352079392317614e-08}.
# tune_lambda_l1_and_lambda_l2, val_score: 4.604077:  25%|##5       | 5/20 [00:00<00:01, 13.58it/s][I 2020-01-25 12:39:18,836] Finished trial#5 resulted in value: 4.703768791762395. Current best value is 4.604076979455367 with parameters: {'lambda_l1': 4.483407399222182e-07, 'lambda_l2': 9.352079392317614e-08}.
# tune_lambda_l1_and_lambda_l2, val_score: 4.573705:  35%|###5      | 7/20 [00:00<00:00, 13.29it/s][I 2020-01-25 12:39:18,919] Finished trial#6 resulted in value: 4.573705442240455. Current best value is 4.573705442240455 with parameters: {'lambda_l1': 0.9005023161427189, 'lambda_l2': 0.4681819102059359}.
# tune_lambda_l1_and_lambda_l2, val_score: 4.330616:  35%|###5      | 7/20 [00:00<00:00, 13.29it/s][I 2020-01-25 12:39:19,008] Finished trial#7 resulted in value: 4.330616175022472. Current best value is 4.330616175022472 with parameters: {'lambda_l1': 0.00027223807830430396, 'lambda_l2': 3.8868893663891564}.
# tune_lambda_l1_and_lambda_l2, val_score: 4.330616:  45%|####5     | 9/20 [00:00<00:00, 12.63it/s][I 2020-01-25 12:39:19,096] Finished trial#8 resulted in value: 4.577534839858038. Current best value is 4.330616175022472 with parameters: {'lambda_l1': 0.00027223807830430396, 'lambda_l2': 3.8868893663891564}.
# tune_lambda_l1_and_lambda_l2, val_score: 4.330616:  45%|####5     | 9/20 [00:00<00:00, 12.63it/s][I 2020-01-25 12:39:19,175] Finished trial#9 resulted in value: 4.6041040683222745. Current best value is 4.330616175022472 with parameters: {'lambda_l1': 0.00027223807830430396, 'lambda_l2': 3.8868893663891564}.
# tune_lambda_l1_and_lambda_l2, val_score: 4.330616:  55%|#####5    | 11/20 [00:00<00:00, 12.48it/s][I 2020-01-25 12:39:19,259] Finished trial#10 resulted in value: 4.503130999847065. Current best value is 4.330616175022472 with parameters: {'lambda_l1': 0.00027223807830430396, 'lambda_l2': 3.8868893663891564}.
# tune_lambda_l1_and_lambda_l2, val_score: 4.330616:  55%|#####5    | 11/20 [00:00<00:00, 12.48it/s][I 2020-01-25 12:39:19,339] Finished trial#11 resulted in value: 4.503144336329143. Current best value is 4.330616175022472 with parameters: {'lambda_l1': 0.00027223807830430396, 'lambda_l2': 3.8868893663891564}.
# tune_lambda_l1_and_lambda_l2, val_score: 4.279852:  65%|######5   | 13/20 [00:01<00:00, 10.38it/s][I 2020-01-25 12:39:19,527] Finished trial#12 resulted in value: 4.279852088314139. Current best value is 4.279852088314139 with parameters: {'lambda_l1': 0.0029385173511272877, 'lambda_l2': 8.280111500565932}.
# tune_lambda_l1_and_lambda_l2, val_score: 4.279852:  65%|######5   | 13/20 [00:01<00:00, 10.38it/s][I 2020-01-25 12:39:19,607] Finished trial#13 resulted in value: 4.294477042955777. Current best value is 4.279852088314139 with parameters: {'lambda_l1': 0.0029385173511272877, 'lambda_l2': 8.280111500565932}.
# tune_lambda_l1_and_lambda_l2, val_score: 4.279852:  75%|#######5  | 15/20 [00:01<00:00, 10.89it/s][I 2020-01-25 12:39:19,692] Finished trial#14 resulted in value: 4.35728261743264. Current best value is 4.279852088314139 with parameters: {'lambda_l1': 0.0029385173511272877, 'lambda_l2': 8.280111500565932}.
# tune_lambda_l1_and_lambda_l2, val_score: 4.279852:  75%|#######5  | 15/20 [00:01<00:00, 10.89it/s][I 2020-01-25 12:39:19,772] Finished trial#15 resulted in value: 4.294228117640447. Current best value is 4.279852088314139 with parameters: {'lambda_l1': 0.0029385173511272877, 'lambda_l2': 8.280111500565932}.
# tune_lambda_l1_and_lambda_l2, val_score: 4.279852:  85%|########5 | 17/20 [00:01<00:00, 11.27it/s][I 2020-01-25 12:39:19,851] Finished trial#16 resulted in value: 4.639107936316012. Current best value is 4.279852088314139 with parameters: {'lambda_l1': 0.0029385173511272877, 'lambda_l2': 8.280111500565932}.
# tune_lambda_l1_and_lambda_l2, val_score: 4.279852:  85%|########5 | 17/20 [00:01<00:00, 11.27it/s][I 2020-01-25 12:39:19,930] Finished trial#17 resulted in value: 4.604081838956623. Current best value is 4.279852088314139 with parameters: {'lambda_l1': 0.0029385173511272877, 'lambda_l2': 8.280111500565932}.
# tune_lambda_l1_and_lambda_l2, val_score: 4.279852:  95%|#########5| 19/20 [00:01<00:00, 10.95it/s][I 2020-01-25 12:39:20,047] Finished trial#18 resulted in value: 4.614806959174448. Current best value is 4.279852088314139 with parameters: {'lambda_l1': 0.0029385173511272877, 'lambda_l2': 8.280111500565932}.
# tune_lambda_l1_and_lambda_l2, val_score: 4.279852:  95%|#########5| 19/20 [00:01<00:00, 10.95it/s][I 2020-01-25 12:39:20,122] Finished trial#19 resulted in value: 4.604115281286804. Current best value is 4.279852088314139 with parameters: {'lambda_l1': 0.0029385173511272877, 'lambda_l2': 8.280111500565932}.
# tune_lambda_l1_and_lambda_l2, val_score: 4.279852: 100%|##########| 20/20 [00:01<00:00, 11.12it/s]
# tune_min_child_samples, val_score: 4.279852:   0%|          | 0/5 [00:00<?, ?it/s][I 2020-01-25 12:39:20,229] Finished trial#0 resulted in value: 4.379357832450247. Current best value is 4.379357832450247 with parameters: {'min_child_samples': 5}.
# tune_min_child_samples, val_score: 4.119394:  40%|####      | 2/5 [00:00<00:00, 14.63it/s][I 2020-01-25 12:39:20,317] Finished trial#1 resulted in value: 4.119394482860049. Current best value is 4.119394482860049 with parameters: {'min_child_samples': 10}.
# tune_min_child_samples, val_score: 4.119394:  40%|####      | 2/5 [00:00<00:00, 14.63it/s][I 2020-01-25 12:39:20,393] Finished trial#2 resulted in value: 4.592548152821914. Current best value is 4.119394482860049 with parameters: {'min_child_samples': 10}.
# tune_min_child_samples, val_score: 4.119394:  80%|########  | 4/5 [00:00<00:00, 14.16it/s][I 2020-01-25 12:39:20,467] Finished trial#3 resulted in value: 5.430413610900758. Current best value is 4.119394482860049 with parameters: {'min_child_samples': 10}.
# tune_min_child_samples, val_score: 4.119394:  80%|########  | 4/5 [00:00<00:00, 14.16it/s][I 2020-01-25 12:39:20,540] Finished trial#4 resulted in value: 7.0064771856400805. Current best value is 4.119394482860049 with parameters: {'min_child_samples': 10}.
# tune_min_child_samples, val_score: 4.119394: 100%|##########| 5/5 [00:00<00:00, 12.10it/s]

# %%
best_params
# Out:
# {'lambda_l1': 0.0029385173511272877,
#  'lambda_l2': 8.280111500565932,
#  'num_leaves': 31,
#  'feature_fraction': 1.0,
#  'bagging_fraction': 0.8764226042397782,
#  'bagging_freq': 5,
#  'min_child_samples': 10}

# %%
param_defaults = {
    'lambda_l1': 0.0,
    'lambda_l2': 0.0,
    'num_leaves': 31,
    'feature_fraction':  1.0,
    'bagging_fraction':  1.0,
    'bagging_freq': 0,
    'min_child_samples': 20
}

# %%
# %matplotlib inline
import pandas as pd
import seaborn as sns

study_vals = []
for h in history:
    vals = {}
    for k, v in best_params.items():
        if k in h['value']:
            dic = eval(h['value'])
            col = k
            val = dic[k]
        else:
            col = k
            val = param_defaults[k]
        vals[col] = val
        vals['score'] = h['val_score']
    study_vals.append(vals)

study_df = pd.DataFrame(study_vals)
sns.pairplot(study_df, kind='reg')

# %% [markdown]
# ## 見つけたパラメータでモデル作成

# %%
import lightgbm as lgb_original
from sklearn.metrics import r2_score

model = lgb_original.train(params, tests, num_boost_round=100)
predicts = model.predict(test_features)
base_r2 = r2_score(test_labels, predicts)

# %%
model = lgb_original.train(best_params, tests, num_boost_round=100)
predicts = model.predict(test_features)
best_r2 = r2_score(test_labels, predicts)

# %%
print(f'Base params: {params}')
print(f'Best params: {best_params}')
print(f'Base: {base_r2}, Best: {best_r2}, Diff: {best_r2 - base_r2}')
# Out:
# Base params: {'objective': 'mean_squared_error', 'metric': 'rmse'}
# Best params: {'lambda_l1': 0.0029385173511272877, 'lambda_l2': 8.280111500565932, 'num_leaves': 31, 'feature_fraction': 1.0, 'bagging_fraction': 0.8764226042397782, 'bagging_freq': 5, 'min_child_samples': 10}
# Base: 0.90643134802633, Best: 0.9557989653668788, Diff: 0.04936761734054884
